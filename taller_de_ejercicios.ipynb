# %% [markdown]
# <a href="https://colab.research.google.com/github/nayverp/Ciencia-de-datos-/blob/main/taller_de_ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #ejercicios del 1 al 5

# %%
base = float(input("Ingrese la base: "))
altura = float(input("Ingrese la altura: "))
area = (base * altura) / 2
print("El area es:", area)
# Out:
# Ingrese la base: 12
# Ingrese la altura: 22
# El area es: 132.0

# %%
c = float(input("Ingrese grados Celsius: "))
f = (c * 9/5) + 32
print("Temperatura en Fahrenheit:", f)
# Out:
# Ingrese grados Celsius: 25
# Temperatura en Fahrenheit: 77.0

# %%
n1 = float(input("Ingrese el primer numero: "))
n2 = float(input("Ingrese el segundo numero: "))
n3 = float(input("Ingrese el tercer numero: "))
promedio = (n1 + n2 + n3) / 3
print("El promedio es:", promedio)
# Out:
# Ingrese el primer numero: 33
# Ingrese el segundo numero: 21
# Ingrese el tercer numero: 44
# El promedio es: 32.666666666666664

# %%
radio = float(input("Ingrese el radio: "))
perimetro = 2 * 3.1416 * radio
area = 3.1416 * radio * radio
print("Perimetro:", perimetro)
print("Area:", area)
# Out:
# Ingrese el radio: 54
# Perimetro: 339.2928
# Area: 9160.9056

# %%
a = float(input("Ingrese a: "))
b = float(input("Ingrese b: "))
c = float(input("Ingrese c: "))
discriminante = (b*b) - (4*a*c)
x1 = (-b + discriminante**0.5) / (2*a)
x2 = (-b - discriminante**0.5) / (2*a)
print("Solucion x1:", x1)
print("Solucion x2:", x2)
# Out:
# Ingrese a: 2
# Ingrese b: 5
# Ingrese c: 9
# Solucion x1: (-1.25+1.713913650100261j)
# Solucion x2: (-1.25-1.713913650100261j)

# %% [markdown]
# #ejercicios del 6 al 10

# %%
numero = int(input("Ingrese un numero: "))
if numero % 2 == 0:
    print("El numero es par")
else:
    print("El numero es impar")
# Out:
# Ingrese un numero: 77
# El numero es impar

# %%
añio = int(input("Ingrese el año: "))
if (añio % 4 == 0 and añio % 100 != 0) or (añio % 400 == 0):
    print("Es un año bisiesto")
else:
    print("No es un año bisiesto")
# Out:
# Ingrese el año: 2024
# Es un año bisiesto

# %%
nombre = input("Ingrese su nombre: ")
edad = int(input("Ingrese su edad: "))
if edad >= 70:
    print(nombre, "tiene prioridad en la fila")
else:
    print(nombre, "no tiene prioridad")
# Out:
# Ingrese su nombre: nayver
# Ingrese su edad: 20
# nayver no tiene prioridad

# %%
n1 = float(input("Ingrese el primer numero: "))
n2 = float(input("Ingrese el segundo numero: "))
if n1 > n2:
    print("El mayor es:", n1)
else:
    print("El mayor es:", n2)
# Out:
# Ingrese el primer numero: 12
# Ingrese el segundo numero: 44
# El mayor es: 44.0

# %%
a = float(input("Ingrese lado 1: "))
b = float(input("Ingrese lado 2: "))
c = float(input("Ingrese lado 3: "))
if a == b and b == c:
    print("Triangulo equilatero")
else:
    if a == b or a == c or b == c:
        print("Triangulo isosceles")
    else:
        print("Triangulo escaleno")
# Out:
# Ingrese lado 1: 4
# Ingrese lado 2: 6
# Ingrese lado 3: 8
# Triangulo escaleno

# %% [markdown]
# # ejercicios del 11 al 15

# %%
nombre = input("Ingrese su nombre: ")
peso = float(input("Ingrese su peso (kg): "))
altura = float(input("Ingrese su altura (cm): "))

altura = altura / 100

imc = peso / (altura * altura)

if imc < 18.5:
    categoria = "Bajo peso"
    mensaje = "Debe mejorar su alimentacion"
elif imc < 25:
    categoria = "Normal"
    mensaje = "Mantenga habitos saludables"
elif imc < 30:
    categoria = "Sobrepeso"
    mensaje = "Se recomienda ejercicio"
else:
    categoria = "Obesidad"
    mensaje = "Consulte a un especialista"

print(nombre, "su IMC es:", imc)
print("Categoria:", categoria)
print("Recomendacion:", mensaje)
# Out:
# Ingrese su nombre: nayver
# Ingrese su peso (kg): 94
# Ingrese su altura (cm): 180
# nayver su IMC es: 29.012345679012345
# Categoria: Sobrepeso
# Recomendacion: Se recomienda ejercicio

# %%
n1 = float(input("Ingrese primer numero: "))
n2 = float(input("Ingrese segundo numero: "))
op = input("Operacion (+, -, *, /): ")
if op == "+":
    resultado = n1 + n2
elif op == "-":
    resultado = n1 - n2
elif op == "*":
    resultado = n1 * n2
elif op == "/":
    resultado = n1 / n2
else:
    resultado = "Operacion no valida"
print("Resultado:", resultado)
# Out:
# Ingrese primer numero: 6
# Ingrese segundo numero: 6
# Operacion (+, -, *, /): *
# Resultado: 36.0

# %%
nota = int(input("Ingrese la nota (0-100): "))
if nota >= 90:
    letra = "A"
elif nota >= 80:
    letra = "B"
elif nota >= 70:
    letra = "C"
elif nota >= 60:
    letra = "D"
else:
    letra = "F"
print("Calificacion:", letra)
# Out:
# Ingrese la nota (0-100): 90
# Calificacion: A

# %%
dia = int(input("Ingrese numero (1-7): "))
if dia == 1:
    nombre = "Lunes"
elif dia == 2:
    nombre = "Martes"
elif dia == 3:
    nombre = "Miercoles"
elif dia == 4:
    nombre = "Jueves"
elif dia == 5:
    nombre = "Viernes"
elif dia == 6:
    nombre = "Sabado"
elif dia == 7:
    nombre = "Domingo"
else:
    nombre = "Numero invalido"
print("Dia:", nombre)
# Out:
# Ingrese numero (1-7): 6
# Dia: Sabado

# %%
a = float(input("Ingrese lado 1: "))
b = float(input("Ingrese lado 2: "))
c = float(input("Ingrese lado 3: "))
if a + b > c and a + c > b and b + c > a:
    if a == b and b == c:
        tipo = "Equilatero"
    elif a == b or a == c or b == c:
        tipo = "Isosceles"
    else:
        tipo = "Escaleno"
    print("Si forma triangulo:", tipo)
else:
    print("No forma un triangulo")
# Out:
# Ingrese lado 1: 12
# Ingrese lado 2: 15
# Ingrese lado 3: 15
# Si forma triangulo: Isosceles
