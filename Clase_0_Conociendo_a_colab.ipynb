# %% [markdown]
# #Ejercicio de ingreso
# Agenda
# 1. Inserción de bloques de texto
# 2. Inserción de titulos

# %% [markdown]
# ##Limpieza de datos

# %% [markdown]
# se aprende a usar el comando print y el uso de comentario

# %%
#este es un comentario
print("hola mundo")
# Out:
# hola mundo
